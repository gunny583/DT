# %% [markdown]
# # Vectorized String Operations

# %% [markdown]
# string(문자열)을 다루는 Pandas 기능을 살펴보자. 특히 vectorized operation으로 구현되어 효율적이다.

# %% [markdown]
# ## Introducing Pandas String Operations

# %%
import numpy as np
x = np.array([2, 3, 5, 7, 11, 13])
x * 2
# Out:
# array([ 4,  6, 10, 14, 22, 26])

# %% [markdown]
# 위와 같이 NumPy 숫자 array의 경우 효과적인 vector operation이 제공된다.
# 그러나 문자열인 경우에는 그렇지 못하므로 loop를 통해 접근해야 한다.

# %%
data = ['peter', 'Paul', 'MARY', 'gUIDO']
[s.capitalize() for s in data]
# Out:
# ['Peter', 'Paul', 'Mary', 'Guido']

# %% [markdown]
# 더구나 missing value에 대한 처리도 주의해야 한다.

# %%
data = ['peter', 'Paul', None, 'MARY', 'gUIDO']
[s.capitalize() for s in data]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-3b0264c38d59> in <module>()
#       1 data = ['peter', 'Paul', None, 'MARY', 'gUIDO']
# ----> 2 [s.capitalize() for s in data]
#
# <ipython-input-3-3b0264c38d59> in <listcomp>(.0)
#       1 data = ['peter', 'Paul', None, 'MARY', 'gUIDO']
# ----> 2 [s.capitalize() for s in data]
#
# AttributeError: 'NoneType' object has no attribute 'capitalize'

# %% [markdown]
# Pandas에서는 ``str``속성을 사용하여 vector operation과 missing value에 대한 처리를 기본적으로 제공한다.

# %%
import pandas as pd
names = pd.Series(data)
names
# Out:
# 0    peter
# 1     Paul
# 2     None
# 3     MARY
# 4    gUIDO
# dtype: object

# %%
names.str.capitalize()
# Out:
# 0    Peter
# 1     Paul
# 2     None
# 3     Mary
# 4    Guido
# dtype: object

# %% [markdown]
# ``str`` 속성을 이용한 많은 다른 함수들이 포함되어 있다.

# %% [markdown]
# ## Tables of Pandas String Methods

# %%
monte = pd.Series(['Graham Chapman', 'John Cleese', 'Terry Gilliam',
                   'Eric Idle', 'Terry Jones', 'Michael Palin'])

# %% [markdown]
# ### Methods similar to Python string methods
# 거의 모든  Python built-in 문자열  method에 대응하는 Pandas Series 객체내``str`` method가 있다.
#
# |             |                  |                  |                  |
# |-------------|------------------|------------------|------------------|
# |``len()``    | ``lower()``      | ``translate()``  | ``islower()``    |
# |``ljust()``  | ``upper()``      | ``startswith()`` | ``isupper()``    |
# |``rjust()``  | ``find()``       | ``endswith()``   | ``isnumeric()``  |
# |``center()`` | ``rfind()``      | ``isalnum()``    | ``isdecimal()``  |
# |``zfill()``  | ``index()``      | ``isalpha()``    | ``split()``      |
# |``strip()``  | ``rindex()``     | ``isdigit()``    | ``rsplit()``     |
# |``rstrip()`` | ``capitalize()`` | ``isspace()``    | ``partition()``  |
# |``lstrip()`` |  ``swapcase()``  |  ``istitle()``   | ``rpartition()`` |

# %%
monte.str.lower()
# Out:
# 0    graham chapman
# 1       john cleese
# 2     terry gilliam
# 3         eric idle
# 4       terry jones
# 5     michael palin
# dtype: object

# %%
monte.str.len()
# Out:
# 0    14
# 1    11
# 2    13
# 3     9
# 4    11
# 5    13
# dtype: int64

# %%
monte.str.startswith('T')
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
monte.str.split()
# Out:
# 0    [Graham, Chapman]
# 1       [John, Cleese]
# 2     [Terry, Gilliam]
# 3         [Eric, Idle]
# 4       [Terry, Jones]
# 5     [Michael, Palin]
# dtype: object

# %% [markdown]
# ### Methods using regular expressions
#
# 또한 정규표현식(RE; regular expression)을 지원하며 하며 Python's built-in ``re`` module에서 제공하는 방식을 많이 따른다.
#
# | Method | Description |
# |--------|-------------|
# | ``match()`` | Call ``re.match()`` on each element, returning a boolean. |
# | ``extract()`` | Call ``re.match()`` on each element, returning matched groups as strings.|
# | ``findall()`` | Call ``re.findall()`` on each element |
# | ``replace()`` | Replace occurrences of pattern with some other string|
# | ``contains()`` | Call ``re.search()`` on each element, returning a boolean |
# | ``count()`` | Count occurrences of pattern|
# | ``split()``   | Equivalent to ``str.split()``, but accepts regexps |
# | ``rsplit()`` | Equivalent to ``str.rsplit()``, but accepts regexps |

# %% [markdown]
# 따라서 문자열 처리가 요구되는 경우 유용하다.

# %%
monte
# Out:
# 0    Graham Chapman
# 1       John Cleese
# 2     Terry Gilliam
# 3         Eric Idle
# 4       Terry Jones
# 5     Michael Palin
# dtype: object

# %%
monte.str.extract('([A-Za-z]+)', expand=False)
# Out:
# 0     Graham
# 1       John
# 2      Terry
# 3       Eric
# 4      Terry
# 5    Michael
# dtype: object

# %% [markdown]
# 문자열의 처음과 끝을 표현하는 (``^``) 과 (``$``) 등을 사용해 보자.

# %%
monte.str.findall(r'^[^AEIOU].*[^aeiou]$')
# Out:
# 0    [Graham Chapman]
# 1                  []
# 2     [Terry Gilliam]
# 3                  []
# 4       [Terry Jones]
# 5     [Michael Palin]
# dtype: object
