# %% [markdown]
# # Pivot Tables

# %% [markdown]
# ``GroupBy``보다 편리하게 데이터 사이의 관계를 보여주는 기능을 *pivot table*을 통해 제공한다.
#
# 특히 *pivot table*은 다차원 grouping을 편리하게 제공하는 장점이 있다.

# %% [markdown]
# ## Motivating Pivot Tables
#
# Seaborn library에 포함되어 있는 *Titanic* 승객 정보 데이터를 이용하여 학습해 보자.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %% [markdown]
# ## Pivot Tables by Hand
# 앞서 배운 ``GroupBy``를 이용하여 성별에 따른 생존율을 계산해 보자.

# %%
titanic.groupby('sex')[['survived']].mean()
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %% [markdown]
# 이번에는 성별과 등급에 따른 생존율을 계산해 보자.

# %%
titanic.groupby(['sex', 'class'])['survived'].aggregate('mean').unstack()
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %% [markdown]
# 이보다 더 편리하게 Pandas ``pivot_table``을 이용하여 구현할 수 있다.

# %% [markdown]
# ## Pivot Table Syntax

# %%
titanic.pivot_table('survived', index='sex', columns='class')
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %% [markdown]
# ### Multi-level pivot tables
#
# 다음과 같이 Multi-level 로 pivot table를 생성할 수 있다.

# %%
age = pd.cut(titanic['age'], [0, 18, 80])
titanic.pivot_table('survived', ['sex', age], 'class')
# Out:
# class               First    Second     Third
# sex    age
# female (0, 18]   0.909091  1.000000  0.511628
#        (18, 80]  0.972973  0.900000  0.423729
# male   (0, 18]   0.800000  0.600000  0.215686
#        (18, 80]  0.375000  0.071429  0.133663

# %% [markdown]
# column역시 multiple level로 바꿀 수 있다. (결국 4차원 분류)

# %%
fare = pd.qcut(titanic['fare'], 2)
titanic.pivot_table('survived', ['sex', age], [fare, 'class'])
# Out:
# fare            (-0.001, 14.454]            ... (14.454, 512.329]
# class                      First    Second  ...            Second     Third
# sex    age                                  ...
# female (0, 18]               NaN  1.000000  ...          1.000000  0.318182
#        (18, 80]              NaN  0.880000  ...          0.914286  0.391304
# male   (0, 18]               NaN  0.000000  ...          0.818182  0.178571
#        (18, 80]              0.0  0.098039  ...          0.030303  0.192308
#
# [4 rows x 6 columns]

# %% [markdown]
# ### Additional pivot table options
#
# ``pivot_table`` method의 전체 형식은 다음과 같으면 여러 option을 제공한다.
#
# ```python
# # call signature as of Pandas 0.18
# DataFrame.pivot_table(data, values=None, index=None, columns=None,
#                       aggfunc='mean', fill_value=None, margins=False,
#                       dropna=True, margins_name='All')
# ```
#
# 그 중 몇가지를 살펴본다.

# %%
titanic.pivot_table(index='sex', columns='class',
                    aggfunc={'survived':sum, 'fare':'mean'})
# Out:
#               fare                       survived
# class        First     Second      Third    First Second Third
# sex
# female  106.125798  21.970121  16.118810       91     70    72
# male     67.226127  19.741782  12.661633       45     17    47

# %% [markdown]
# ``margins`` keyword을 이용하여 total을 구할 수 있다.

# %%
titanic.pivot_table('survived', index='sex', columns='class', margins=True)
# Out:
# class      First    Second     Third       All
# sex
# female  0.968085  0.921053  0.500000  0.742038
# male    0.368852  0.157407  0.135447  0.188908
# All     0.629630  0.472826  0.242363  0.383838
