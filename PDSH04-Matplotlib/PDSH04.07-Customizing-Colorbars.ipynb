# %% [markdown]
# # Customizing Colorbars

# %% [markdown]
# 범례와 달리 연속값에 대한 표지를 위해 Colorbar는 유용한 도구이다.

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')

# %%
# %matplotlib inline
import numpy as np

# %% [markdown]
# As we have seen several times throughout this section, the simplest colorbar can be created with the ``plt.colorbar`` function:

# %%
x = np.linspace(0, 10, 1000)
I = np.sin(x) * np.cos(x[:, np.newaxis])

plt.imshow(I)
plt.colorbar();

# %% [markdown]
# ## Customizing Colorbars

# %%
plt.imshow(I, cmap='gray');

# %% [markdown]
# 사용 가능한 colormap 명은 ``plt.cm`` namespace에 있으며 앞서 배웠듯이 다음과 같이 리스트해 볼 수 있다.
# ```
# plt.cm.<TAB>
# ```
